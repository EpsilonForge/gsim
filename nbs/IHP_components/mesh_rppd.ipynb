# %%
from ihp import PDK
from ihp.cells.resistors import rppd
from gsim.palace import DrivenSim
from pathlib import Path

PDK.activate()
#yaml_file = Path("~/Documents/IHP/ihp/s_parameters/ihp_stack.yaml").expanduser()
yaml_file = Path("~/projects/IHP/ihp/s_parameters/ihp_stack.yaml").expanduser()

# %%
c = rppd()

keep_layers = [
    (128, 0),  # PolyResdrawing  
    (8, 0),    # Metal1drawing
    (8, 2),    # Metal1pin
]

cc = c.extract(layers=keep_layers)
cc.add_ports(c.ports)

c.draw_ports()
c.plot()

# %%
# Checking the port layers.
cc.ports
# Out:
# ["Port(self.name='P1', self.width=460, trans=r90 *1 0.25,0.78, layer=Metal1pin (8/2), port_type=electrical)", "Port(self.name='P2', self.width=460, trans=r270 *1 0.25,-0.28, layer=Metal1pin (8/2), port_type=electrical)"]

# %%
sim = DrivenSim()
sim.set_output_dir("runs/palace-sim-rppd")
sim.set_geometry(cc)

sim.set_stack(substrate_thickness=2.0,air_above=5.0)

sim.add_port("P1",layer="metal1")
sim.add_port("P2",layer="metal1")

sim.set_driven(fmin=1e9, fmax=100e9, num_points=60)

print(sim.validate_config())
# Out:
# Validation: PASSED

# %%
# TODO: investigate why Z dimension is much larger than expected.
sim.mesh(preset="graded",refined_mesh_size=0.2)
# Out:
# Mesh Summary
# ========================================
# Dimensions: 100.5 x 101.4 x 23.3 µm
# Nodes:      394
# Elements:   2,732
# Tetrahedra: 2,018
# Edge length: 0.08 - 53.76 µm
# Quality:    0.560 (min: 0.023)
# SICN:       0.602 (all valid)
# ----------------------------------------
# Volumes (3):
#   - SiO2 [1]
#   - passive [2]
#   - air [3]
# Surfaces (11):
#   - metal1_xy [4]
#   - metal1_z [5]
#   - polyres_xy [6]
#   - polyres_z [7]
#   - P1 [8]
#   - P2 [9]
#   - SiO2__None [10]
#   - SiO2__passive [11]
#   - passive__None [12]
#   - air__passive [13]
#   - air__None [14]
# ----------------------------------------
# Mesh:   runs/palace-sim-rppd/palace.msh

# %%
sim.plot_mesh(show_groups=["metal","P","poly","heatres"],interactive=False)
# Out:
# 2026-04-01 03:49:22.755 (   0.631s) [    758B1F9DA080]vtkXOpenGLRenderWindow.:1460  WARN| bad X server connection. DISPLAY=
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# 2026-04-01 03:49:22.767 (   0.643s) [    758B1F9DA080]vtkEGLRenderWindowInter:218   WARN| EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# 2026-04-01 03:49:22.785 (   0.661s) [    758B1F9DA080]vtkEGLRenderWindowInter:218   WARN| EGL device index: 0 could not be initialized. Trying other devices...
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# libEGL warning: failed to open /dev/dri/renderD128: Permission denied
#
# 2026-04-01 03:49:22.826 (   0.702s) [    758B1F9DA080]vtkEGLRenderWindowInter:218   WARN| EGL device index: 0 could not be initialized. Trying other devices...

# %%
results = sim.run(parent_dir="runs")
# Out:
#   palace-bd86da98  completed  0m 12s
# Extracting results.tar.gz...
# Downloaded 11 files to runs/sim-data-palace-bd86da98

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv(results["port-S.csv"])
df.columns = df.columns.str.strip()  # Remove whitespace from column names

freq = df["f (GHz)"]

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 6))

# Magnitude plot
ax1.plot(freq, df["|S[1][1]| (dB)"], marker=".", label="S11")
ax1.plot(freq, df["|S[2][1]| (dB)"], marker=".", label="S21")
ax1.set_xlabel("Frequency (GHz)")
ax1.set_ylabel("Magnitude (dB)")
ax1.set_title("S-Parameters")
ax1.legend()
ax1.grid(True)

# Phase plot
ax2.plot(freq, df["arg(S[1][1]) (deg.)"], marker=".", label="S11")
ax2.plot(freq, df["arg(S[2][1]) (deg.)"], marker=".", label="S21")
ax2.set_xlabel("Frequency (GHz)")
ax2.set_ylabel("Phase (deg)")
ax2.legend()
ax2.grid(True)

plt.tight_layout()
