# %% [markdown]
# # Running Palace Simulations
#
# [Palace](https://awslabs.github.io/palace/) is an open-source 3D electromagnetic simulator supporting eigenmode, driven (S-parameter), and electrostatic simulations. This notebook demonstrates using the `gsim.palace` API to run a driven simulation on a CPW (coplanar waveguide) structure.
#
# **Requirements:**
#
# - IHP PDK: `uv pip install ihp-gdsfactory`
# - [GDSFactory+](https://gdsfactory.com) account for cloud simulation

# %% [markdown]
# ### Load a pcell from IHP PDK

# %%
import gdsfactory as gf
from ihp import LAYER, PDK

PDK.activate()


@gf.cell
def gsg_electrode(
    length: float = 300,
    s_width: float = 20,
    g_width: float = 40,
    gap_width: float = 15,
    layer=LAYER.TopMetal2drawing,
) -> gf.Component:
    """
    Create a GSG (Ground-Signal-Ground) electrode.

    Args:
        length: horizontal length of the electrodes
        s_width: width of the signal (center) electrode
        g_width: width of the ground electrodes
        gap_width: gap between signal and ground electrodes
        layer: layer for the metal
    """
    c = gf.Component()

    # Top ground electrode
    r1 = c << gf.c.rectangle((length, g_width), centered=True, layer=layer)
    r1.move((0, (g_width + s_width) / 2 + gap_width))

    # Center signal electrode
    _r2 = c << gf.c.rectangle((length, s_width), centered=True, layer=layer)

    # Bottom ground electrode
    r3 = c << gf.c.rectangle((length, g_width), centered=True, layer=layer)
    r3.move((0, -(g_width + s_width) / 2 - gap_width))

    # Add ports at the signal center (one per side)
    # The CPW port API computes the gap element surfaces from s_width and gap_width
    c.add_port(
        name="o1",
        center=(-length / 2, 0),
        width=s_width,
        orientation=0,
        port_type="electrical",
        layer=layer,
    )

    c.add_port(
        name="o2",
        center=(length / 2, 0),
        width=s_width,
        orientation=180,
        port_type="electrical",
        layer=layer,
    )

    return c


c = gsg_electrode()
cc = c.copy()
cc.draw_ports()
cc

# %% [markdown]
# ### Configure and run simulation with DrivenSim

# %%
from gsim.palace import DrivenSim

# Create simulation object
sim = DrivenSim()

# Set output directory
sim.set_output_dir("./palace-sim-cpw")

# Set the component geometry
sim.set_geometry(c)

# Configure layer stack from active PDK
sim.set_stack(substrate_thickness=2.0, air_above=300.0)

# Configure left CPW port (single port at signal center)
sim.add_cpw_port("o1", layer="topmetal2", s_width=20, gap_width=15, length=5.0)

# Configure right CPW port (single port at signal center)
sim.add_cpw_port("o2", layer="topmetal2", s_width=20, gap_width=15, length=5.0)

# Configure driven simulation (frequency sweep for S-parameters)
sim.set_driven(fmin=1e9, fmax=100e9, num_points=40)

# Validate configuration
print(sim.validate_config())
# Out:
# Validation: PASSED

# %%
# Generate mesh with planar conductors (presets: "coarse", "default", "fine")
sim.mesh(preset="default", planar_conductors=False)
# Out:
# /home/martin/Desktop/gsim/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3701: UserWarning: Preset 'default' values overridden by: planar_conductors=False
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Warning : 2 ill-shaped tets are still in the mesh
# Warning : ------------------------------
# Warning : Mesh generation error summary
# Warning :     1 warning
# Warning :     0 errors
# Warning : Check the full log for details
# Warning : ------------------------------
# Warning : 2 ill-shaped tets are still in the mesh
# Warning : ------------------------------
# Warning : Mesh generation error summary
# Warning :     1 warning
# Warning :     0 errors
# Warning : Check the full log for details
# Warning : ------------------------------
# Mesh Summary
# ========================================
# Dimensions: 600.0 x 430.0 x 516.6 µm
# Nodes:      3,960
# Elements:   31,340
# Tetrahedra: 22,730
# Edge length: 0.40 - 307.99 µm
# Quality:    0.469 (min: 0.001)
# SICN:       0.520 (all valid)
# ----------------------------------------
# Volumes (4):
#   - air [1]
#   - passive [2]
#   - SiO2 [3]
#   - airbox [4]
# Surfaces (12):
#   - topmetal2_xy [5]
#   - topmetal2_z [6]
#   - P1_E0 [7]
#   - P1_E1 [8]
#   - P2_E0 [9]
#   - P2_E1 [10]
#   - Absorbing_boundary [11]
#   - air__airbox [12]
#   - air__passive [13]
#   - airbox__passive [14]
#   - SiO2__passive [15]
#   - SiO2__airbox [16]
# ----------------------------------------
# Mesh:   palace-sim-cpw/palace.msh

# %%
# Static PNG (wireframe, filtered to metal + port groups)
# sim.plot_mesh(show_groups=["metal", "P"], interactive=False)

# Interactive wireframe
# sim.plot_mesh(show_groups=["metal", "P"], interactive=True)

# Solid view — coloured surfaces per physical group, boundary transparent
sim.plot_mesh(style="solid", transparent_groups=["Absorbing_boundary", "air__airbox", "air__passive"], interactive=True)
# Out:
# /home/martin/Desktop/gsim/src/gsim/viz.py:260: UserWarning: Failed to use notebook backend:
#
# No module named 'trame.app'
#
# Falling back to a static output.
#   plotter.show()
# <PIL.Image.Image image mode=RGB size=1200x900>

# %% [markdown]
# ### Run simulation on cloud

# %%
# Run simulation on GDSFactory+ cloud
results = sim.run()

# Run locally (requires local installation of Palace)
# sim.write_config()# results = sim.run_local()
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# Cell In[9], line 2
#       1 # Run simulation on GDSFactory+ cloud
# ----> 2 results = sim.run()
#       4 # Run locally (requires local installation of Palace)
#       5 # sim.write_config()# results = sim.run_local()
#
# File ~/Desktop/gsim/src/gsim/palace/driven.py:810, in DrivenSim.run(self, parent_dir, verbose, wait)
#     779 def run(
#     780     self,
#     781     parent_dir: str | Path | None = None,
#    (...)    784     wait: bool = True,
#     785 ) -> dict[str, Path] | str:
#     786     """Run simulation on GDSFactory+ cloud.
#     787
#     788     Requires mesh() to be called first. Automatically calls
#    (...)    808         >>> print(f"S-params saved to: {results['port-S.csv']}")
#     809     """
# --> 810     self.upload(verbose=False)
#     811     self.start(verbose=verbose)
#     812     if not wait:
#
# File ~/Desktop/gsim/src/gsim/palace/driven.py:713, in DrivenSim.upload(self, verbose)
#     711 tmp = self._prepare_upload_dir()
#     712 try:
# --> 713     self._job_id = gcloud.upload(tmp, "palace", verbose=verbose)
#     714 except Exception:
#     715     import shutil
#
# File ~/Desktop/gsim/src/gsim/gcloud.py:272, in upload(config_dir, job_type, verbose)
#     269 if verbose:
#     270     print("Uploading simulation... ", end="", flush=True)  # noqa: T201
# --> 272 pre_job = upload_simulation_dir(config_dir, job_type)
#     274 if verbose:
#     275     print(f"done (job_id: {pre_job.job_id})")  # noqa: T201
#
# File ~/Desktop/gsim/src/gsim/gcloud.py:502, in upload_simulation_dir(input_dir, job_type)
#     500 input_dir = Path(input_dir)
#     501 job_definition = _get_job_definition(job_type)
# --> 502 return sim.upload_simulation(path=input_dir, job_definition=job_definition)
#
# File ~/Desktop/gsim/.venv/lib/python3.12/site-packages/gdsfactoryplus/sim.py:144, in upload_simulation(path, job_definition, job_name, job_queue_name)
#     141 # Build queue name if provided
#     142 queue_name = _build_job_queue_name(job_queue_name) if job_queue_name else None
# --> 144 prepare_response = _prepare_job(
#     145     job_name, path.name, job_definition_name, queue_name
#     146 )
#     147 _upload_file(prepare_response.upload_url, path)
#     148 return PreJob(
#     149     job_id=prepare_response.job_id,
#     150     job_name=job_name,
#     151 )
#
# File ~/Desktop/gsim/.venv/lib/python3.12/site-packages/gdsfactoryplus/sim.py:352, in _prepare_job(job_name, original_file_name, job_definition_name, job_queue_name)
#     346 with httpx.Client(timeout=TIMEOUT) as client:
#     347     response = client.post(
#     348         f"{_base_url()}/job/prepare",
#     349         headers=_headers(),
#     350         json=payload,
#     351     )
# --> 352     response.raise_for_status()
#     353     data = response.json()
#     354     return PrepareJobResponse.model_validate(data["data"])
#
# File ~/Desktop/gsim/.venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     827 error_type = error_types.get(status_class, "Invalid status code")
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '401 Unauthorized' for url 'https://api.gdsfactory.com/api/simulation/sdk/v1/job/prepare'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/401

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv(results["port-S.csv"])
df.columns = df.columns.str.strip()  # Remove whitespace from column names

freq = df["f (GHz)"]

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 6))

# Magnitude plot
ax1.plot(freq, df["|S[1][1]| (dB)"], marker=".", label="S11")
ax1.plot(freq, df["|S[2][1]| (dB)"], marker=".", label="S21")
ax1.set_xlabel("Frequency (GHz)")
ax1.set_ylabel("Magnitude (dB)")
ax1.set_title("S-Parameters")
ax1.legend()
ax1.grid(True)

# Phase plot
ax2.plot(freq, df["arg(S[1][1]) (deg.)"], marker=".", label="S11")
ax2.plot(freq, df["arg(S[2][1]) (deg.)"], marker=".", label="S21")
ax2.set_xlabel("Frequency (GHz)")
ax2.set_ylabel("Phase (deg)")
ax2.legend()
ax2.grid(True)

plt.tight_layout()
